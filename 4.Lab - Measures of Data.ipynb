# %% [markdown]
# ## Lab Brief - Statistical Learning with Python

# %% [markdown]
# ### Part-1

# %% [markdown]
# ## Measures of Data

# %% [markdown]
# Descriptive Statistcs are measures that summarize important features of data. Producing these descriptive statistics is a common first step to take after cleaning and preparing a dataset for further analysis. Examples are like calculating Mean or Median. In this lab, we will be looking into some of these functions and explore several new ones.

# %% [markdown]
# #### Measures of Central Tendency

# %% [markdown]
# Whenever you measure things of the same kind, a fairly large number of such measurements will tend to cluster around the middle value. Such a value is called a measure of "Central Tendency". The other terms that are used synonymously are "Measures of Location", or "Statistical Averages".

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

mtcars = pd.read_csv('mtcars.csv')

# %% [markdown]
# ##### Using the mtcars dataset.
#
# For the below set of questions, we will be using the cars data from [Motor Trend Car Road Tests](http://stat.ethz.ch/R-manual/R-devel/library/datasets/html/mtcars.html)
#
# The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
#
#
# Details :
#
# A data frame with 32 observations on 11 (numeric) variables.
#
# [, 1] 	mpg 	Miles/(US) gallon
#
# [, 2] 	cyl 	Number of cylinders
#
# [, 3] 	disp 	Displacement (cu.in.)
#
# [, 4] 	hp 	Gross horsepower
#
# [, 5] 	drat 	Rear axle ratio
#
# [, 6] 	wt 	Weight (1000 lbs)
#
# [, 7] 	qsec 	1/4 mile time
#
# [, 8] 	vs 	Engine (0 = V-shaped, 1 = straight)
#
# [, 9] 	am 	Transmission (0 = automatic, 1 = manual)
#
# [,10] 	gear 	Number of forward gears
#
# [,11] 	carb 	Number of carburetors

# %% [markdown]
# #### Explore the data - Setting the index

# %%
mtcars.index = mtcars["name"]
mtcars.head()
# mtcars.mean() #By default this will give the mean of each column
# Out:
#                                 name   mpg  cyl   disp   hp  drat     wt  \
# name
# Mazda RX4                  Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
#
#                     qsec  vs  am  gear  carb
# name
# Mazda RX4          16.46   0   1     4     4
# Mazda RX4 Wag      17.02   0   1     4     4
# Datsun 710         18.61   1   1     4     1
# Hornet 4 Drive     19.44   1   0     3     1
# Hornet Sportabout  17.02   0   0     3     2

# %% [markdown]
# ### Question 1
#
# What is the first car name given in mtcars?
#
# ** Make use of index which has been set previously **
#
# **Hint**: Use .loc function

# %%
mtcars.loc['Mazda RX4','name']
# Out:
# 'Mazda RX4'

# %% [markdown]
# ### Question 2
# What is the highest difference between the hp and cyl?
#
# **Hint:** You can use **max()** function to find the difference

# %%
max(mtcars['hp']-mtcars['cyl'])
# Out:
# 327

# %% [markdown]
# ### Question 3
# What are the cars having highest weight(wt) and lowest weight(wt)?
#
# **Hint:** Use idxmax() and idxmin() to locate the row
#
# Use **.iloc** function to print the  row
#
# **Note:** Both idxmax and idxmin belong to pandas

# %%
mtcars["wt"].idxmax()
# Out:
# 'Lincoln Continental'

# %%
mtcars['wt'].idxmin()
# Out:
# 'Lotus Europa'

# %% [markdown]
# ### Question 4
#
# Find the mean of each row and each column in the given dataset.
#
# **Hint:** Use .mean() function. To operate on rows use **axis=0**, on columns use **axis=1**

# %%
mtcars.mean(axis=0)
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
mtcars.mean(axis=1)
# Out:
# name
# Mazda RX4              29.907273
# Mazda RX4 Wag          29.981364
# Datsun 710             23.598182
# Hornet 4 Drive         38.739545
# Hornet Sportabout      53.664545
# Valiant                35.049091
# Duster 360             59.720000
# Merc 240D              24.634545
# Merc 230               27.233636
# Merc 280               31.860000
# Merc 280C              31.787273
# Merc 450SE             46.430909
# Merc 450SL             46.500000
# Merc 450SLC            46.350000
# Cadillac Fleetwood     66.232727
# Lincoln Continental    66.058545
# Chrysler Imperial      65.972273
# Fiat 128               19.440909
# Honda Civic            17.742273
# Toyota Corolla         18.814091
# Toyota Corona          24.888636
# Dodge Challenger       47.240909
# AMC Javelin            46.007727
# Camaro Z28             58.752727
# Pontiac Firebird       57.379545
# Fiat X1-9              18.928636
# Porsche 914-2          24.779091
# Lotus Europa           24.880273
# Ford Pantera L         60.971818
# Ferrari Dino           34.508182
# Maserati Bora          63.155455
# Volvo 142E             26.262727
# dtype: float64

# %% [markdown]
# ### Question 5
#
# Plot mpg values of mtcards dataframe using matplotlib.
#
# **Hint: Use plt.plot function**

# %%
mtcars['mpg'].plot()

# %% [markdown]
# ## Part 2

# %% [markdown]
# ## Measures of Dispersion

# %% [markdown]
# Measures of Dispersion (Spread) are statistics that describe how data varies. Measure of dispersion gives us the sense of how much the data tends to diverge from the central tendency.

# %% [markdown]
# ### Question 6
#
# What the range of `mpg` in the given dataset?
#
# **Hint:** Range = max-min

# %%
max(mtcars['mpg'])-min(mtcars['mpg'])
# Out:
# 23.5

# %% [markdown]
# ### Question 7
#
# Calculate the 25th quantile (lower quantile)for `mpg` in the given dataset.
#
# **Hint:** Use **.quantile()**

# %%
mtcars['mpg'].quantile(.25)
# Out:
# 15.425

# %% [markdown]
# ### Question 8
#
# Calculate the Inter-Quartile Range(IQR) for `mpg` in the given dataset.

# %% [markdown]
# Interquartile range (IQR) is another common measure of spread. IQR is the distance between the 3rd quartile and the 1st quartile.
#
# **Hint:** IQR = Q3 - Q1

# %%
mtcars['mpg'].quantile(0.75)-mtcars['mpg'].quantile(.25)
# Out:
# 7.375

# %% [markdown]
# ### Question 9
#
# Calculate the Variance, Standard Deviation and Median Absolute Deviation for `mpg`.

# %% [markdown]
# Variance and Standard Deviation are two other common measure of dispersion.
#
# **Hint:** Use .var() and .std()

# %% [markdown]
# **Hint:** Median Absolute Deviation - alternative measure of spread based on the median. It is the median of the absolute value of the deviations from the median.

# %%
mtcars['mpg'].var()
# Out:
# 36.32410282258065

# %%
mtcars['mpg'].std()
# Out:
# 6.026948052089105

# %%
mtcars['mpg'].mad()
# Out:
# 4.714453125

# %% [markdown]
# ## Part 3

# %% [markdown]
# ## Probability Distributions

# %% [markdown]
# The probability distribution describes how a random variable is distributed. It tells us which values a variable is most likely to take on and which values are less likely to take on.

# %% [markdown]
# Each value in the given range is equally likely to occur.

# %%
import scipy.stats as stats # Many functions for probability distributions in python are in scipy.stats

# %% [markdown]
# ### Question 10
#
# Generate 1000 datapoints with standard normal distribution with mean 0 and standard deviation 1.

# %% [markdown]
# #### Normal Distribution

# %% [markdown]
# The normal or Gaussian Distribution is a continuos probability distribution given by a symmetric bell shaped curve. It is defined its center(mean) and spread(std).

# %% [markdown]
# The bulk of the observations generated from a normal distribution lie near the mean which lies at the center. About 68% of the data lies within 1 std, 95% lies within 2 stds and 99.7% lies within 3 stds.
#
# **Hint:** You can use **np.random.normal()** function to generate normal distribution

# %%
np.random.normal(0,1,1000)
# Out:
# array([-6.60700861e-01,  4.96731678e-01, -6.64202475e-02,  9.87885921e-02,
#         7.90123316e-01, -9.89774753e-01, -1.36811415e+00, -1.23422155e+00,
#         1.00505070e+00,  1.51371769e+00,  1.05071012e-01,  1.09144785e+00,
#         1.31115248e+00, -1.28279170e+00, -2.44958436e-01,  1.08197618e+00,
#        -4.83361664e-01,  6.66339552e-01,  9.88544881e-01,  2.35668494e-01,
#         1.02867237e+00, -1.18128829e-01, -1.69528891e+00,  6.37420033e-01,
#         2.87501152e-01,  3.15267810e-01, -2.37131358e+00, -5.66266192e-01,
#         4.08137028e-01, -1.36470897e+00,  7.29595696e-01,  5.27550555e-01,
#        -1.06454362e+00,  1.42153253e-01, -3.05705123e-01,  7.65098745e-01,
#         2.05409288e-01,  1.26510049e+00, -6.70926846e-01,  1.19580946e-01,
#        -8.85494742e-01, -6.26159101e-01,  5.88782704e-01, -6.06390752e-01,
#         1.02955167e+00,  1.98151199e-01, -1.42281607e-01, -5.18159751e-02,
#        -1.43026352e+00, -1.26578413e+00,  2.79630166e-01,  8.49555144e-01,
#        -1.32390093e+00,  4.55505067e-01, -3.26836175e-01, -1.26050677e+00,
#         2.92446122e-01, -2.83229734e-01,  7.55214461e-01,  1.74512839e+00,
#        -7.55807610e-02, -9.95400442e-02, -5.22938460e-01, -9.90894478e-02,
#        -7.39876542e-01,  3.77959459e-01, -3.63080546e-01, -9.94532703e-01,
#         6.87101304e-01,  3.82828691e-01,  4.86555786e-01,  2.11772681e+00,
#         2.76649055e-01,  8.14856521e-01, -1.18489741e-01,  9.76290780e-01,
#        -8.06492691e-01, -2.98030907e-01,  3.10437084e-01, -2.20310272e-01,
#         5.68821870e-01,  7.42992046e-01,  1.14652667e+00, -5.95239555e-01,
#         8.85810586e-01, -4.55444869e-01,  8.84317187e-01, -1.96452772e-01,
#         4.02364519e-01,  4.58569719e-01,  9.66219875e-01,  6.73457717e-01,
#        -1.95516538e+00, -6.06550886e-01,  1.68217287e-01, -1.20558767e+00,
#         1.11593352e+00,  8.43949712e-01, -5.25591607e-01, -1.04859041e+00,
#         7.12176133e-01, -4.03042860e-01, -3.23545525e-01, -8.91477297e-01,
#         3.44409843e-01, -2.12543936e-01, -5.91238831e-01,  8.61379856e-01,
#         1.83622306e-01,  1.22539930e+00, -5.60136529e-01,  7.47079459e-01,
#        -2.73421900e-01,  4.49029681e-02, -2.79543972e-01,  8.55641609e-01,
#        -3.68014167e-01,  3.49961101e-01,  1.78361701e+00,  4.20643142e-01,
#         4.82685278e-01, -3.98037286e-01, -1.50620888e+00,  1.02351434e+00,
#         2.04071026e-01, -1.16881559e+00,  2.68823366e-01, -1.69488817e+00,
#        -9.94451159e-02, -1.18573735e+00,  2.02172888e-01,  7.10155488e-01,
#        -7.41667623e-01, -5.80159414e-01, -2.47056813e+00, -1.07740921e+00,
#         2.20585656e-01, -9.62979929e-01,  7.93681300e-01,  2.82757922e+00,
#         1.26561478e-01,  8.39647269e-01,  1.54272795e+00,  5.06308511e-01,
#        -1.00294994e+00,  4.47016102e-01,  4.33583554e-01, -2.54363180e-01,
#        -1.59535295e+00,  8.80016000e-01, -1.04555950e+00, -1.70572045e-01,
#         1.13303763e-01,  1.44004028e+00, -1.42980915e+00,  4.00623574e-01,
#        -1.12395755e+00,  1.99325901e+00, -8.94851202e-01,  1.26680328e+00,
#         1.86260642e-02, -1.43673454e+00, -1.21709149e+00,  1.80663682e-01,
#         4.66898719e-01,  1.09625499e-01,  1.15904269e+00, -5.72850449e-01,
#        -1.38188609e-01,  2.09148891e+00,  1.13599521e-01, -1.49794444e-01,
#         1.55745999e+00,  7.83424400e-01, -8.76475339e-01, -1.16257254e-01,
#        -1.21702469e+00,  2.95488492e-01,  3.01537164e-01,  1.41817042e+00,
#        -1.02837333e+00,  2.15222502e-01, -1.74479004e+00, -4.60147515e-01,
#         1.65435270e+00, -1.26943727e+00, -1.98453051e-01, -7.06312828e-01,
#         6.51165649e-01,  8.30539826e-01, -3.09009128e-01,  5.77126764e-01,
#        -1.70872512e-01, -6.04266106e-01, -1.50105339e+00,  1.72552071e+00,
#        -2.86126991e-01, -2.96482227e-02,  5.69272799e-01,  1.52789179e+00,
#        -1.16494926e+00, -3.89364483e-01,  1.18318559e+00,  1.55646445e+00,
#        -8.23408525e-01, -3.71961819e-01, -1.10708913e+00, -1.03000807e+00,
#         7.53584126e-01, -7.84146698e-01, -9.61685170e-02,  4.60134676e-01,
#        -5.79836584e-02,  1.73817080e-01, -8.44199336e-01, -1.36907042e-01,
#         1.98826138e+00,  5.06572791e-01,  1.87185354e-01,  1.38616675e+00,
#         7.20706220e-01, -1.50010859e-01, -1.48533515e+00, -2.98745417e-01,
#        -3.23481326e-01,  1.19660759e+00,  1.87925263e-01,  4.83465177e-01,
#        -6.20901456e-01,  8.60126571e-01, -6.54414203e-01, -8.26712208e-02,
#         1.21560772e+00, -1.49560747e+00,  1.68343547e+00, -1.10062131e+00,
#        -8.79896663e-01,  8.12090321e-01,  7.49084224e-01, -1.45011782e+00,
#         9.97195262e-01, -9.74240653e-01,  1.51281275e+00, -6.60418581e-02,
#        -1.30676190e+00, -9.97937206e-01, -3.72514431e-01, -2.41622204e-01,
#        -6.55533184e-01, -6.68771917e-01, -1.55207988e+00,  9.50054857e-01,
#        -4.03429151e-01,  2.00743176e+00,  1.56384010e+00,  4.68489068e-02,
#        -1.12841926e+00, -2.51718645e-01, -1.30816638e+00, -8.46867136e-01])

# %% [markdown]
# ## Question 11
#
# Generate binomial distribution data for fair coin flipping of size 100. Assume `0` for head and `1` for tail.
#
# [ **Hint:** For fair coin flip `p=0.5` ]

# %% [markdown]
# #### Binomial Distribution

# %% [markdown]
# It is defined by 2 parameters: the probability of success and the number of trails. It tells about how likely it is possible to get a given number of successes in n trails.

# %%
n=100
p=0.5
k=np.arange(0,101)
k
binomial = stats.binom.pmf(k,n,p)
binomial
# Out:
# array([7.88860905e-31, 7.88860905e-29, 3.90486148e-27, 1.27558808e-25,
#        3.09330110e-24, 5.93913812e-23, 9.40363535e-22, 1.26277389e-20,
#        1.46797465e-19, 1.50059631e-18, 1.36554264e-17, 1.11726216e-16,
#        8.28636101e-16, 5.60922899e-15, 3.48573516e-14, 1.99848816e-13,
#        1.06169683e-12, 5.24603142e-12, 2.41900338e-11, 1.04399093e-10,
#        4.22816327e-10, 1.61072886e-09, 5.78398092e-09, 1.96152396e-08,
#        6.29322272e-08, 1.91313971e-07, 5.51867223e-07, 1.51252498e-06,
#        3.94336870e-06, 9.79043264e-06, 2.31706906e-05, 5.23209142e-05,
#        1.12816971e-04, 2.32471335e-04, 4.58105277e-04, 8.63855666e-04,
#        1.55973940e-03, 2.69792760e-03, 4.47287998e-03, 7.11073227e-03,
#        1.08438667e-02, 1.58690732e-02, 2.22922695e-02, 3.00686426e-02,
#        3.89525598e-02, 4.84742966e-02, 5.79583981e-02, 6.65905000e-02,
#        7.35270104e-02, 7.80286641e-02, 7.95892374e-02, 7.80286641e-02,
#        7.35270104e-02, 6.65905000e-02, 5.79583981e-02, 4.84742966e-02,
#        3.89525598e-02, 3.00686426e-02, 2.22922695e-02, 1.58690732e-02,
#        1.08438667e-02, 7.11073227e-03, 4.47287998e-03, 2.69792760e-03,
#        1.55973940e-03, 8.63855666e-04, 4.58105277e-04, 2.32471335e-04,
#        1.12816971e-04, 5.23209142e-05, 2.31706906e-05, 9.79043264e-06,
#        3.94336870e-06, 1.51252498e-06, 5.51867223e-07, 1.91313971e-07,
#        6.29322272e-08, 1.96152396e-08, 5.78398092e-09, 1.61072886e-09,
#        4.22816327e-10, 1.04399093e-10, 2.41900338e-11, 5.24603142e-12,
#        1.06169683e-12, 1.99848816e-13, 3.48573516e-14, 5.60922899e-15,
#        8.28636101e-16, 1.11726216e-16, 1.36554264e-17, 1.50059631e-18,
#        1.46797465e-19, 1.26277389e-20, 9.40363535e-22, 5.93913812e-23,
#        3.09330110e-24, 1.27558808e-25, 3.90486148e-27, 7.88860905e-29,
#        7.88860905e-31])

# %%
np.random.binomial(100,0.5,100)
# Out:
# array([58, 51, 54, 43, 44, 57, 50, 51, 51, 51, 56, 54, 53, 57, 55, 42, 57,
#        46, 51, 55, 55, 49, 52, 61, 52, 51, 49, 47, 53, 45, 50, 46, 53, 43,
#        58, 62, 47, 41, 44, 47, 47, 47, 43, 43, 54, 47, 52, 41, 44, 44, 48,
#        47, 49, 51, 58, 60, 50, 46, 55, 59, 49, 49, 49, 45, 45, 49, 47, 52,
#        42, 52, 49, 50, 36, 53, 51, 41, 52, 47, 45, 52, 47, 48, 55, 51, 56,
#        52, 41, 52, 56, 56, 52, 43, 53, 52, 59, 45, 44, 51, 48, 44])

# %% [markdown]
# #### Visualizing Poisson Distribution

# %% [markdown]
# It models the probability of seeing certain number of successes within a time interval.

# %%
poisson_data = stats.poisson.rvs(size=100,mu=10)

pd.DataFrame(poisson_data).hist()

plt.show()
